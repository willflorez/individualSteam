# %% [markdown]
# IMPORTANDO

# %%
import pandas as pd
import json
# %load_ext autoreload
# %autoreload 2
import utils
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# EXTRAYENDO

# %%
ruta_games = 'output_steam_games.json'
filas_games = []
with open(ruta_games) as f:
    for line in f.readlines():
        data = json.loads(line)
        filas_games.append(data)
df_games = pd.DataFrame(filas_games)
df_games
# Out:
#               publisher                                 genres  \
# 0                   NaN                                    NaN
# 1                   NaN                                    NaN
# 2                   NaN                                    NaN
# 3                   NaN                                    NaN
# 4                   NaN                                    NaN
# ...                 ...                                    ...
# 120440  Ghost_RUS Games  [Casual, Indie, Simulation, Strategy]
# 120441           Sacada              [Casual, Indie, Strategy]
# 120442     Laush Studio            [Indie, Racing, Simulation]
# 120443         SIXNAILS                        [Casual, Indie]
# 120444              NaN                                    NaN
#
#                         app_name                     title  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# 2                            NaN                       NaN
# 3                            NaN                       NaN
# 4                            NaN                       NaN
# ...                          ...                       ...
# 120440            Colony On Mars            Colony On Mars
# 120441  LOGistICAL: South Africa  LOGistICAL: South Africa
# 120442             Russian Roads             Russian Roads
# 120443       EXIT 2 - Directions       EXIT 2 - Directions
# 120444               Maze Run VR                       NaN
#
#                                                       url release_date  \
# 0                                                     NaN          NaN
# 1                                                     NaN          NaN
# 2                                                     NaN          NaN
# 3                                                     NaN          NaN
# 4                                                     NaN          NaN
# ...                                                   ...          ...
# 120440  http://store.steampowered.com/app/773640/Colon...   2018-01-04
# 120441  http://store.steampowered.com/app/733530/LOGis...   2018-01-04
# 120442  http://store.steampowered.com/app/610660/Russi...   2018-01-04
# 120443  http://store.steampowered.com/app/658870/EXIT_...   2017-09-02
# 120444  http://store.steampowered.com/app/681550/Maze_...          NaN
#
#                                                      tags  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 120440              [Strategy, Indie, Casual, Simulation]
# 120441                          [Strategy, Indie, Casual]
# 120442                        [Indie, Simulation, Racing]
# 120443  [Indie, Casual, Puzzle, Singleplayer, Atmosphe...
# 120444  [Early Access, Adventure, Indie, Action, Simul...
#
#                                               reviews_url  discount_price  \
# 0                                                     NaN             NaN
# 1                                                     NaN             NaN
# 2                                                     NaN             NaN
# 3                                                     NaN             NaN
# 4                                                     NaN             NaN
# ...                                                   ...             ...
# 120440  http://steamcommunity.com/app/773640/reviews/?...            1.49
# 120441  http://steamcommunity.com/app/733530/reviews/?...            4.24
# 120442  http://steamcommunity.com/app/610660/reviews/?...            1.39
# 120443  http://steamcommunity.com/app/658870/reviews/?...             NaN
# 120444  http://steamcommunity.com/app/681550/reviews/?...             NaN
#
#                                                     specs price early_access  \
# 0                                                     NaN   NaN          NaN
# 1                                                     NaN   NaN          NaN
# 2                                                     NaN   NaN          NaN
# 3                                                     NaN   NaN          NaN
# 4                                                     NaN   NaN          NaN
# ...                                                   ...   ...          ...
# 120440                [Single-player, Steam Achievements]  1.99        False
# 120441  [Single-player, Steam Achievements, Steam Clou...  4.99        False
# 120442  [Single-player, Steam Achievements, Steam Trad...  1.99        False
# 120443   [Single-player, Steam Achievements, Steam Cloud]  4.99        False
# 120444  [Single-player, Stats, Steam Leaderboards, HTC...  4.99         True
#
#             id metascore                 developer            user_id  \
# 0          NaN       NaN                       NaN  76561197970982479
# 1          NaN       NaN                       NaN            js41637
# 2          NaN       NaN                       NaN          evcentric
# 3          NaN       NaN                       NaN         Riot-Punch
# 4          NaN       NaN                       NaN              doctr
# ...        ...       ...                       ...                ...
# 120440  773640       NaN        Nikita "Ghost_RUS"                NaN
# 120441  733530       NaN                    Sacada                NaN
# 120442  610660       NaN  Laush Dmitriy Sergeevich                NaN
# 120443  658870       NaN             xropi,stev3ns                NaN
# 120444  681550       NaN                       NaN                NaN
#
#                  steam_id                                              items  \
# 0       76561197970982479  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 1       76561198035864385  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 2       76561198007712555  [{'item_id': '1200', 'item_name': 'Red Orchest...
# 3       76561197963445855  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 4       76561198002099482  [{'item_id': '300', 'item_name': 'Day of Defea...
# ...                   ...                                                ...
# 120440                NaN                                                NaN
# 120441                NaN                                                NaN
# 120442                NaN                                                NaN
# 120443                NaN                                                NaN
# 120444                NaN                                                NaN
#
#         items_count
# 0             277.0
# 1             888.0
# 2             137.0
# 3             328.0
# 4             541.0
# ...             ...
# 120440          NaN
# 120441          NaN
# 120442          NaN
# 120443          NaN
# 120444          NaN
#
# [120445 rows x 19 columns]

# %%
df_games.to_csv('games.csv', index =  False)

# %%
df_games = pd.read_csv('games.csv')

# %% [markdown]
# ELIMINANDO REGISTROS

# %%
df_games.isnull().sum()
# Out:
# publisher          96362
# genres             91593
# app_name           88312
# title              90360
# url                88310
# release_date       90377
# tags               88473
# reviews_url        88312
# discount_price    120220
# specs              88980
# price              89687
# early_access       88310
# id                 88312
# metascore         117768
# developer          91609
# user_id            32135
# steam_id           32135
# items              32135
# items_count        32135
# dtype: int64

# %%
df_games = df_games.dropna(how='all').reset_index(drop=True)
df_games.shape
# Out:
# (120445, 19)

# %%
df_games.dropna(subset = ['id'], inplace = True)

# %%
df_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32133 entries, 88310 to 120444
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   publisher       24082 non-null  object
#  1   genres          28851 non-null  object
#  2   app_name        32132 non-null  object
#  3   title           30084 non-null  object
#  4   url             32133 non-null  object
#  5   release_date    30067 non-null  object
#  6   tags            31971 non-null  object
#  7   reviews_url     32133 non-null  object
#  8   discount_price  224 non-null    float64
#  9   specs           31464 non-null  object
#  10  price           30756 non-null  object
#  11  early_access    32133 non-null  object
#  12  id              32133 non-null  object
#  13  metascore       2676 non-null   object
#  14  developer       28835 non-null  object
#  15  user_id         0 non-null      object
#  16  steam_id        0 non-null      object
#  17  items           0 non-null      object
#  18  items_count     0 non-null      float64
# dtypes: float64(2), object(17)
# memory usage: 4.9+ MB

# %% [markdown]
# TRANSFORMACION DE RELEASE_DATE

# %%
# Se observan las cantidades de registros por cada fecha
df_games['release_date'].value_counts()
# Out:
# release_date
# 2012-10-16    100
# 2017-08-31     92
# 2017-09-26     89
# 2017-06-21     82
# 2017-07-25     78
#              ...
# 1988-04-16      1
# 2013-08-24      1
# 2011-05-07      1
# 2010-08-21      1
# 2018-10-01      1
# Name: count, Length: 3582, dtype: int64

# %%
# Crea columna nueva con el año
df_games['release_anio'] = df_games['release_date'].apply(utils.obtener_anio_release)
# elimina la columna 'release_date'
df_games = df_games.drop('release_date', axis=1)
df_games.head()
# Out:
#               publisher                                             genres  \
# 88310         Kotoshiro      [Action, Casual, Indie, Simulation, Strategy]
# 88311  Making Fun, Inc.               [Free to Play, Indie, RPG, Strategy]
# 88312      Poolians.com  [Casual, Free to Play, Indie, Simulation, Sports]
# 88313              彼岸领域                        [Action, Adventure, Casual]
# 88314               NaN                                                NaN
#
#                       app_name                    title  \
# 88310      Lost Summoner Kitty      Lost Summoner Kitty
# 88311                Ironbound                Ironbound
# 88312  Real Pool 3D - Poolians  Real Pool 3D - Poolians
# 88313                  弹炸人2222                  弹炸人2222
# 88314            Log Challenge                      NaN
#
#                                                      url  \
# 88310  http://store.steampowered.com/app/761140/Lost_...
# 88311  http://store.steampowered.com/app/643980/Ironb...
# 88312  http://store.steampowered.com/app/670290/Real_...
# 88313     http://store.steampowered.com/app/767400/2222/
# 88314  http://store.steampowered.com/app/773570/Log_C...
#
#                                                     tags  \
# 88310      [Strategy, Action, Indie, Casual, Simulation]
# 88311  [Free to Play, Strategy, Indie, RPG, Card Game...
# 88312  [Free to Play, Simulation, Sports, Casual, Ind...
# 88313                        [Action, Adventure, Casual]
# 88314                    [Action, Indie, Casual, Sports]
#
#                                              reviews_url  discount_price  \
# 88310  http://steamcommunity.com/app/761140/reviews/?...            4.49
# 88311  http://steamcommunity.com/app/643980/reviews/?...             NaN
# 88312  http://steamcommunity.com/app/670290/reviews/?...             NaN
# 88313  http://steamcommunity.com/app/767400/reviews/?...            0.83
# 88314  http://steamcommunity.com/app/773570/reviews/?...            1.79
#
#                                                    specs         price  \
# 88310                                    [Single-player]          4.99
# 88311  [Single-player, Multi-player, Online Multi-Pla...  Free To Play
# 88312  [Single-player, Multi-player, Online Multi-Pla...  Free to Play
# 88313                                    [Single-player]          0.99
# 88314  [Single-player, Full controller support, HTC V...          2.99
#
#       early_access      id metascore         developer user_id steam_id items  \
# 88310        False  761140       NaN         Kotoshiro     NaN      NaN   NaN
# 88311        False  643980       NaN  Secret Level SRL     NaN      NaN   NaN
# 88312        False  670290       NaN      Poolians.com     NaN      NaN   NaN
# 88313        False  767400       NaN              彼岸领域     NaN      NaN   NaN
# 88314        False  773570       NaN               NaN     NaN      NaN   NaN
#
#        items_count        release_anio
# 88310          NaN                2018
# 88311          NaN                2018
# 88312          NaN                2017
# 88313          NaN                2017
# 88314          NaN  Dato no disponible

# %% [markdown]
# TRABAJANDO CON PRICES

# %%
df_games['price'] = df_games['price'].apply(utils.reemplaza_a_flotante)
df_games['price'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# TRANSFORMANDO MAS COLUMNAS

# %%
# SColumnas a transformar
columnas_a_completar = ['publisher', 'app_name', 'title', 'developer']
# Se rellenan los nulos
df_relleno = df_games[columnas_a_completar].fillna('Sin dato disponible')
# Se borran las columnas originales y se concatenan las rellenas con todo el dataframe
df_games = pd.concat([df_games.drop(columnas_a_completar, axis=1), df_relleno], axis=1)
df_games.head()
# Out:
#                                                   genres  \
# 88310      [Action, Casual, Indie, Simulation, Strategy]
# 88311               [Free to Play, Indie, RPG, Strategy]
# 88312  [Casual, Free to Play, Indie, Simulation, Sports]
# 88313                        [Action, Adventure, Casual]
# 88314                                                NaN
#
#                                                      url  \
# 88310  http://store.steampowered.com/app/761140/Lost_...
# 88311  http://store.steampowered.com/app/643980/Ironb...
# 88312  http://store.steampowered.com/app/670290/Real_...
# 88313     http://store.steampowered.com/app/767400/2222/
# 88314  http://store.steampowered.com/app/773570/Log_C...
#
#                                                     tags  \
# 88310      [Strategy, Action, Indie, Casual, Simulation]
# 88311  [Free to Play, Strategy, Indie, RPG, Card Game...
# 88312  [Free to Play, Simulation, Sports, Casual, Ind...
# 88313                        [Action, Adventure, Casual]
# 88314                    [Action, Indie, Casual, Sports]
#
#                                              reviews_url  discount_price  \
# 88310  http://steamcommunity.com/app/761140/reviews/?...            4.49
# 88311  http://steamcommunity.com/app/643980/reviews/?...             NaN
# 88312  http://steamcommunity.com/app/670290/reviews/?...             NaN
# 88313  http://steamcommunity.com/app/767400/reviews/?...            0.83
# 88314  http://steamcommunity.com/app/773570/reviews/?...            1.79
#
#                                                    specs  price early_access  \
# 88310                                    [Single-player]   4.99        False
# 88311  [Single-player, Multi-player, Online Multi-Pla...   0.00        False
# 88312  [Single-player, Multi-player, Online Multi-Pla...   0.00        False
# 88313                                    [Single-player]   0.99        False
# 88314  [Single-player, Full controller support, HTC V...   2.99        False
#
#            id metascore user_id steam_id items  items_count  \
# 88310  761140       NaN     NaN      NaN   NaN          NaN
# 88311  643980       NaN     NaN      NaN   NaN          NaN
# 88312  670290       NaN     NaN      NaN   NaN          NaN
# 88313  767400       NaN     NaN      NaN   NaN          NaN
# 88314  773570       NaN     NaN      NaN   NaN          NaN
#
#              release_anio            publisher                 app_name  \
# 88310                2018            Kotoshiro      Lost Summoner Kitty
# 88311                2018     Making Fun, Inc.                Ironbound
# 88312                2017         Poolians.com  Real Pool 3D - Poolians
# 88313                2017                 彼岸领域                  弹炸人2222
# 88314  Dato no disponible  Sin dato disponible            Log Challenge
#
#                          title            developer
# 88310      Lost Summoner Kitty            Kotoshiro
# 88311                Ironbound     Secret Level SRL
# 88312  Real Pool 3D - Poolians         Poolians.com
# 88313                  弹炸人2222                 彼岸领域
# 88314      Sin dato disponible  Sin dato disponible

# %%
columnas_a_eliminar = ['discount_price', 'metascore', 'user_id', 'steam_id', 'items', 'items_count']

df_games = df_games.drop(columnas_a_eliminar, axis=1)

# %%
df_games = df_games.explode('genres')
df_games = df_games.dropna(subset=['genres'])
df_games.head()
# Out:
#            genres                                                url  \
# 88310      Action  http://store.steampowered.com/app/761140/Lost_...
# 88310      Casual  http://store.steampowered.com/app/761140/Lost_...
# 88310       Indie  http://store.steampowered.com/app/761140/Lost_...
# 88310  Simulation  http://store.steampowered.com/app/761140/Lost_...
# 88310    Strategy  http://store.steampowered.com/app/761140/Lost_...
#
#                                                 tags  \
# 88310  [Strategy, Action, Indie, Casual, Simulation]
# 88310  [Strategy, Action, Indie, Casual, Simulation]
# 88310  [Strategy, Action, Indie, Casual, Simulation]
# 88310  [Strategy, Action, Indie, Casual, Simulation]
# 88310  [Strategy, Action, Indie, Casual, Simulation]
#
#                                              reviews_url            specs  \
# 88310  http://steamcommunity.com/app/761140/reviews/?...  [Single-player]
# 88310  http://steamcommunity.com/app/761140/reviews/?...  [Single-player]
# 88310  http://steamcommunity.com/app/761140/reviews/?...  [Single-player]
# 88310  http://steamcommunity.com/app/761140/reviews/?...  [Single-player]
# 88310  http://steamcommunity.com/app/761140/reviews/?...  [Single-player]
#
#        price early_access      id release_anio  publisher  \
# 88310   4.99        False  761140         2018  Kotoshiro
# 88310   4.99        False  761140         2018  Kotoshiro
# 88310   4.99        False  761140         2018  Kotoshiro
# 88310   4.99        False  761140         2018  Kotoshiro
# 88310   4.99        False  761140         2018  Kotoshiro
#
#                   app_name                title  developer
# 88310  Lost Summoner Kitty  Lost Summoner Kitty  Kotoshiro
# 88310  Lost Summoner Kitty  Lost Summoner Kitty  Kotoshiro
# 88310  Lost Summoner Kitty  Lost Summoner Kitty  Kotoshiro
# 88310  Lost Summoner Kitty  Lost Summoner Kitty  Kotoshiro
# 88310  Lost Summoner Kitty  Lost Summoner Kitty  Kotoshiro

# %%
df_games = df_games.drop(['tags', 'specs', 'url', 'reviews_url'], axis=1)
df_games.columns
# Out:
# Index(['genres', 'price', 'early_access', 'id', 'release_anio', 'publisher',
#        'app_name', 'title', 'developer'],
#       dtype='object')

# %%
# Se verifica como quedan los tipos de datos y si hay nulos
utils.verificar_tipo_datos(df_games)
# Out:
#    nombre_campo         tipo_datos  no_nulos_%  nulos_%  nulos
# 0        genres    [<class 'str'>]       100.0      0.0      0
# 1         price  [<class 'float'>]       100.0      0.0      0
# 2  early_access   [<class 'bool'>]       100.0      0.0      0
# 3            id    [<class 'str'>]       100.0      0.0      0
# 4  release_anio    [<class 'str'>]       100.0      0.0      0
# 5     publisher    [<class 'str'>]       100.0      0.0      0
# 6      app_name    [<class 'str'>]       100.0      0.0      0
# 7         title    [<class 'str'>]       100.0      0.0      0
# 8     developer    [<class 'str'>]       100.0      0.0      0

# %%
df_games = pd.read_csv('games.csv')

# %%
df_games.to_csv('games.csv', index = False)
